# %% [markdown]
# # ⭐ stable-diffuison-webui-colab by er1cw00

# %%
from IPython.display import Markdown, display
#@title ## 🚩 Install stable-diffusion-webui
#@markdown ### ▶️ Install stable-diffusion-webui

display(Markdown('## 🔄 Install stable-diffusion-webui ....'))

# !apt -y update -qq
# !wget https://github.com/camenduru/gperftools/releases/download/v1.0/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
# %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4
# %env TF_CPP_MIN_LOG_LEVEL=1

# !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev ffmpeg
# !pip install -q torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 torchtext==0.15.2 torchdata==0.6.1 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.20 triton==2.0.0 gradio_client==0.2.7 -U
# !rm -rf /content/stable-diffusion-webui
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui.git /content/stable-diffusion-webui

display(Markdown('## ✅ Download stable-diffusion-webui finished!'))

# %%
from IPython.display import Markdown, display
#@title ## 🚩 Install Extensions
#@markdown ### ▶️ Install Extensions

sd_extension_images_browser = True #@param {type:"boolean"}
sd_extension_huggingface    = False #@param {type:"boolean"}
sd_extension_civitai        = True #@param {type:"boolean"}
sd_extension_controlnet     = True #@param {type:"boolean"}
sd_extension_rembg          = True #@param  {type:"boolean"}
sd_extensionafter_detailer  = True #@param {type:"boolean"}

display(Markdown('## 🔄 Install stable-diffusion-webui extensions ...'))

if sd_extension_images_browser == True:
  print('📄 Install stable-diffusion-webui-images-browser')
  # !git clone https://github.com/camenduru/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/sd-webui-images-browser
if sd_extension_huggingface == True:
  print('📄 Install stable-diffusion-webui-huggingface')
  # !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/sd-webui-huggingface
if sd_extension_civitai == True:
  print('📄 Install sd-civitai-browser')
  # !git clone https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser
if sd_extension_controlnet == True:
  print('📄 Install sd-webui-controlnet')
  # !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
if sd_extension_rembg == True:
  print('📄 Install stable-diffusion-webui-rembg')
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg /content/stable-diffusion-webui/extensions/sd-webui-rembg
if sd_extensionafter_detailer == True:
  print('📄 Install !AfterDetailer')
  # !git clone https://github.com/Bing-su/adetailer.git /content/stable-diffusion-webui/extensions/sd-webui-adetailer


display(Markdown('## ✅ Download stable-diffusion-webui extensions success'))

# %%
import os
from IPython.display import Markdown, display

#@title ## 🚩 Install ControlNet Models
#@markdown ### ▶️ Install ControlNet Models

controlnet_model_path = '/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models'

sd_controlnet_openpose = True #@param {type:"boolean"}
sd_controlnet_canny    = False #@param {type:"boolean"}
sd_controlnet_inpaint  = False #@param {type:"boolean"}
sd_controlnet_tile     = False #@param {type:"boolean"}

sd_controlnet_qrcode_monster          = True #@param {type:"boolean"}
sd_controlnet_qrcode_pattern          = True #@param {type:"boolean"}
sd_controlnet_qrcode_ioc_brightness   = False #@param {type:"boolean"}
sd_controlnet_qrcode_ioc_illumination = False #@param {type:"boolean"}

display(Markdown('## ✅ Start download models of Extensions ... '))

if sd_controlnet_openpose == True:
  print('📄 download Control Openpose model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth -d {controlnet_model_path} -o control_v11p_sd15_openpose.pth
if sd_controlnet_canny == True:
  print('📄 download Control Canny model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth -d {controlnet_model_path} -o control_v11p_sd15_canny.pth
if sd_controlnet_inpaint == True:
  print('📄 download Control Inpaint model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth -d {controlnet_model_path} -o control_v11p_sd15_inpaint.pth
if sd_controlnet_tile == True:
  print('📄 download Control Tile model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth -d {controlnet_model_path} -o control_v11f1e_sd15_tile.pth


if sd_controlnet_qrcode_ioc_illumination == True:
  print('📄 download IoCLab Illumination model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ioclab/ioc-controlnet/resolve/main/models/control_v1p_sd15_brightness.safetensors -d {controlnet_model_path} -o control_v1p_sd15_illumination.safetensors

if sd_controlnet_qrcode_ioc_brightness == True:
  print('📄 download IoCLab Brightness model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ioclab/ioc-controlnet/resolve/main/models/control_v1p_sd15_illumination.safetensors -d {controlnet_model_path} -o control_v1p_sd15_brightness.safetensors

if sd_controlnet_qrcode_pattern == True:
  print('📄 download QRCodePattern model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/111973 -d {controlnet_model_path} -o controlnetQRPatternQR_v2Sd15

if sd_controlnet_qrcode_monster == True:
  print('📄 download QRCodeMonster model')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.yaml -d {controlnet_model_path} -o control_v1p_sd15_qrcode_monster.yaml
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.safetensors -d {controlnet_model_path} -o control_v1p_sd15_qrcode_monster.safetensors

display(Markdown('## ✅ Download models of Extensions success!'))

# %%
import os
from IPython.display import Markdown, display
#@title ## 🚩 Install Models
#@markdown ### ▶️ Install Checkpoint

sd_checkpoint_MajicMix_v6  = True #@param {type:"boolean"}
sd_checkpoint_MarsMix      = False #@param {type:"boolean"}
sd_checkpoint_AresMix      = False #@param {type:"boolean"}
sd_checkpoint_BRAv6        = False #@param {type:"boolean"}
sd_checkpoint_ChilloutMix  = False #@param {type:"boolean"}

#@markdown ### ▶️ Install Embedding:
sd_embedding_negative    = True #@param {type:"boolean"}

checkpoint_model_path = '/content/stable-diffusion-webui/models/Stable-diffusion'

# install checkpoint
display(Markdown('## 🔄 Start download Checkpoint ... '))

if sd_checkpoint_ChilloutMix == True:
  print('📄 download chilloutMix checkpoint')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/11745 -d {checkpoint_model_path} -o chilloutmix_NiPrunedFp32Fix.safetensors
if sd_checkpoint_BRAv6 == True:
  print('📄 download beautifulRealistic_v60 checkpoint')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/113479 -d {checkpoint_model_path} -o beautifulRealistic_v60.safetensors
if sd_checkpoint_AresMix == True:
  print('📄 download aresMix_v0.2 checkpoint')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/57295 -d {checkpoint_model_path} -o aresMix_v02.safetensors
if sd_checkpoint_MarsMix == True:
  print('📄 download marsMix_v0.2 checkpoint')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/27008 -d {checkpoint_model_path} -o marsMix_v02.safetensors
if sd_checkpoint_MajicMix_v6 == True:
  print('📄 download majicmixRealistic_v6 checkpoint')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/94640 -d {checkpoint_model_path} -o majicmixRealistic_v6.safetensors

display(Markdown('## ✅ Download Checkpoint success!'))

# install embedding model
display(Markdown('## 🔄 Start download Embedding models ... '))
embedding_model_path='/content/stable-diffusion-webui/embeddings/'
if sd_embedding_negative == True:
  print('📄 download negative embedding models')
  negative_model_path = os.path.join(embedding_model_path, "negative")
  # !rm -rf {negative_model_path}
  # !git clone https://huggingface.co/embed/negative {negative_model_path}
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/AsciiP/badhandv4/resolve/main/badhandv4.pt -d {negative_model_path} -o badhandv4.pt
display(Markdown('## ✅ Download Embedding models success!'))


# install RealESRGAN model
display(Markdown('## 🔄 Start download RealESRGAN models ... '))
realESRGAN_model_path='/content/stable-diffusion-webui/models/RealESRGAN'
# !mkdir -p {realESRGAN_model_path}
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.4/RealESRGAN_x4plus_anime_6B.pth -d {realESRGAN_model_path}-o RealESRGAN_x4plus_anime_6B.pth
display(Markdown('## ✅ Download RealESRGAN models success!'))

# %%
import os
from IPython.display import Markdown, display
#@title ## 🚩 Install Lora Models
#@markdown ### ▶️ Download Lora Models:

sd_rola_chinaDollLikeness_v10     = True #@param {type:"boolean"}
sd_rola_japaneseDollLikeness_v15  = False #@param {type:"boolean"}
sd_rola_koreanDollLikeness_v20    = False #@param {type:"boolean"}
sd_rola_taiwanDollLikeness_v20    = True #@param {type:"boolean"}
sd_rola_thaiDollLikeness_v10      = False #@param {type:"boolean"}
sd_rola_coveredNipples_v20        = False #@param {type:"boolean"}
sd_rola_girlPutBreastOnTable_v1   = False #@param {type:"boolean"}
sd_rola_kitchenApron_v1           = True #@param {type:"boolean"}
sd_rola_undressingPanties_v01     = True #@param {type:"boolean"}
sd_rola_icecreamFeet_v1           = False #@param {type:"boolean"}
sd_rola_tGirls_v3b                = True #@param {type:"boolean"}
sd_rola_libraryBackground_v16     = False #@param {type:"boolean"}
sd_rola_messyRoom_v10             = True #@param {type:"boolean"}

rola_model_path='/content/stable-diffusion-webui/models/Lora'

display(Markdown('## 🔄 Start install LoRA models ...'))

if sd_rola_chinaDollLikeness_v10 == True:
  print('📄 download chinaDollLikeness_v10 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kanbara/doll-likeness-series/resolve/main/chinaDollLikeness_v10.safetensors -d {rola_model_path} -o chinaDollLikeness_v10.safetensors
if sd_rola_japaneseDollLikeness_v15 == True:
  print('📄 download japaneseDollLikeness_v15 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kanbara/doll-likeness-series/resolve/main/japaneseDollLikeness_v15.safetensors -d {rola_model_path} -o japaneseDollLikeness_v15.safetensors
if sd_rola_koreanDollLikeness_v20 == True:
  print('📄 download koreanDollLikeness_v20 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kanbara/doll-likeness-series/resolve/main/koreanDollLikeness_v20.safetensors -d {rola_model_path} -o koreanDollLikeness_v20.safetensors
if sd_rola_taiwanDollLikeness_v20 == True:
  print('📄 download taiwanDollLikeness_v20 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kanbara/doll-likeness-series/resolve/main/taiwanDollLikeness_v20.safetensors -d {rola_model_path} -o taiwanDollLikeness_v20.safetensors
if sd_rola_thaiDollLikeness_v10 == True:
  print('📄 download thaiDollLikeness_v10 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kanbara/doll-likeness-series/resolve/main/ThaiDollLikeness_v10.safetensors -d {rola_model_path} -o thaiDollLikeness_v10.safetensors
if sd_rola_coveredNipples_v20 == True:
  print('📄 download coveredNipples_v20 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/37788 -d {rola_model_path} -o coveredNipples_v20.safetensors
if sd_rola_girlPutBreastOnTable_v1 == True:
  print('📄 download girlPutBreastOnTable_v1 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/123015 -d {rola_model_path} -o TWGirlPutBallsOnTableMix_v1.safetensors
if sd_rola_kitchenApron_v1 == True:
  print('📄 download kitchenApron_v1 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/69722 -d {rola_model_path} -o kitchenApron_v1.safetensors
if sd_rola_undressingPanties_v01 == True:
  print('📄 download undressingPanties_v01 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/119559 -d {rola_model_path} -o undressing_panties_v01.safetensors
if sd_rola_icecreamFeet_v1 == True:
  print('📄 download icecreamFeet_v1 LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/87405 -d {rola_model_path} -o icecreamFeet_v1.safetensors
if sd_rola_tGirls_v3b == True:
  print('📄 download TGirls_v3b LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/36234 -d {rola_model_path} -o tgirl_v3b.safetensors
if sd_rola_libraryBackground_v16 == True:
  print('📄 download libraryBackground LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/125699 -d {rola_model_path} -o libbg_v16.safetensors
if sd_rola_libraryBackground_v16 == True:
  print('📄 download libraryBackground LoRA models')
  # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/63509 -d {rola_model_path} -o messyRoom_v10.safetensors
display(Markdown('## ✅ Install LoRA models success!'))

# %%
import os
import sys
from pyngrok import ngrok, conf

#@title ## 🚩 Run
#@markdown ### ▶️ Start stable-diffusion-webui

#@markdown - Input your ngrok token if you want to use ngrok server
ngrok_token = "" #@param {type:"string"}

#@markdown - Add credentials to your Gradio interface (optional)
gradio_username = "er1cw00" #@param {type:"string"}
gradio_password= "1234" #@param {type:"string"}

if gradio_username == "" or gradio_password== "":
  gradio_auth = ""

gradio_share = ""
if ngrok_token != "":
  ngrok.kill()
  srv=ngrok.connect(7860, pyngrok_config=conf.PyngrokConfig(auth_token=Ngrok_token) , bind_tls=True).public_url

  for line in fileinput.input('/usr/local/lib/python3.10/dist-packages/gradio/blocks.py', inplace=True):
    if line.strip().startswith('self.server_name ='):
        line = f'            self.server_name = "{srv[8:]}"\n'
    if line.strip().startswith('self.protocol = "https"'):
        line = '            self.protocol = "https"\n'
    if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
        line = ''
    if line.strip().startswith('else "http"'):
        line = ''
    sys.stdout.write(line)
elif gradio_username != "" and gradio_password != "":
  gradio_share = '--share'
  gradio_auth=f"--gradio-auth {gradio_username}:{gradio_password}"
else:
  display(Markdown('## 💥 GradioAuth or NgrokToken must be set!'))
  return

display(Markdown('## 🔄 Running stable-diffusion-webui ...'))
# %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4
# %env TF_CPP_MIN_LOG_LEVEL=1

# %cd /content/stable-diffusion-webui
# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark {gradio_share} {gradio_auth}
